# %% [markdown]
# # Approach-1

# %% [markdown]
# ___
# 1. The architecture contains two main layers.
#     - First layer => Light weight ml model to detect discreet value of haze in image
#     - Second layer => Light weight Neural Networks to dehaze the image based on output of the previous layer.
#         - In second layer pass previous layers haze level to NN. Training only on NN.
